# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from sklearn import metrics
import math
# %load_ext autoreload
# %autoreload 2
from python.predictor import model_price, melt_data, create_zip_df, plot_models, plot_model
plt.style.use('fivethirtyeight')

# %%
all_df = pd.read_csv('raw_data/zillow_data.csv')
stats_df = pd.read_csv('raw_data/stats.csv')

# %%
model1, history_df1, forecast_df1, zipcode1 = model_price(all_df, 29601, '2005-04-01', '2018-04-01')
model2, history_df2, forecast_df2, zipcode2 = model_price(all_df, 75234, '2005-04-01', '2018-04-01')
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
zip_forecasts={}
zip_forecasts[29601] = {'history': history_df1, 'forecast': forecast_df1}
zip_forecasts[75234] = {'history': history_df2, 'forecast': forecast_df2}

# %%
zipcodes = [29601, 75234, 75224, 27601, 75235]
zip_forecasts = {}
for zipcode in zipcodes:
    model, history_df, forecast_df, zipcode = model_price(all_df, zipcode, '2005-04-01', '2018-04-01')
    zip_forecasts[zipcode] = {'history': history_df, 'forecast': forecast_df}
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# ...

# %%
plot_models(all_df, stats_df, zip_forecasts, 'Lower Risk')
